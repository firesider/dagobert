# %%
import MetaTrader5 as mt5
from datetime import datetime
import pytz
import pandas as pd

# %%
# Initialize the MetaTrader 5 connection
if not mt5.initialize():
    print("initialize() failed, error code =", mt5.last_error())
    quit()

# %%
# set the timezone to UTC
timezone = pytz.timezone("Etc/UTC")
# create datetime objects in UTC timezone so that local timezone offset is not applied
utc_from = datetime(2024, 1, 1, tzinfo=timezone)
utc_to = datetime(2026, 4, 26, tzinfo=timezone)

rates = mt5.copy_rates_range("EURUSD", mt5.TIMEFRAME_M15, utc_from, utc_to)

# create a DataFrame from the received data
rates_frame = pd.DataFrame(rates)
# convert time from number of seconds to datetime format
rates_frame['time'] = pd.to_datetime(rates_frame['time'], unit = 's')
# export to csv
rates_frame.to_csv('../raw_data/EURUSD_M15_2024-2026.csv', index=False)
# output data
rates_frame.head()
# Out:
#                  time     open     high      low    close  tick_volume  \
# 0 2024-01-02 00:00:00  1.10437  1.10451  1.10415  1.10449           93
# 1 2024-01-02 00:15:00  1.10420  1.10450  1.10420  1.10426           77
# 2 2024-01-02 00:30:00  1.10437  1.10437  1.10415  1.10428           69
# 3 2024-01-02 00:45:00  1.10423  1.10441  1.10411  1.10439          136
# 4 2024-01-02 01:00:00  1.10441  1.10447  1.10380  1.10382          508
#
#    spread  real_volume
# 0      11            0
# 1      13            0
# 2      12            0
# 3      11            0
# 4       3            0
